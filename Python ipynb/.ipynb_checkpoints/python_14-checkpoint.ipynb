# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## read_csv로 데이터를 Dataframe 형태로 불러옴

# %%
file_path = 'data/drinks.csv'
drinks = pd.read_csv(file_path)

# %% [markdown]
# - info() 함수를 통해 결측(NaN) 값을 측정

# %%
print(drinks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB
# None

# %%
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %%
drinks.describe() # 숫자가 아니면 안나온다
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# ## correlation 상관 관계

# %%
corr = drinks[['beer_servings','wine_servings']].corr(method='pearson')
print(corr)
# Out:
# beer_servings  wine_servings
# beer_servings       1.000000       0.527172
# wine_servings       0.527172       1.000000

# %%
cols =['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol']
corr = drinks[cols].corr(method='pearson')
print(corr)
# Out:
# beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns
# corr 행렬 히트맵을 시각화합니다.
cols_view = ['beer', 'spirit', 'wine', 'alcohol'] # 그래프 출력을 위한 cols 이름을 축약합니다.
sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
            cbar=True,
            annot=True, 
            square=True,
            fmt='.2f',
            annot_kws={'size': 15},
            yticklabels=cols_view,
            xticklabels=cols_view)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## scatter plot(삼점도)

# %%
# 시각화 라이브러리를 이용한 피처간의 scatter plot을 출력합니다.
sns.set(style='whitegrid', context='notebook')
sns.pairplot(drinks[['beer_servings', 'spirit_servings', 
                     'wine_servings', 'total_litres_of_pure_alcohol']], height=2.5)
plt.show()

# %% [markdown]
# ## 결측 데이터 전처리

# %%
print(drinks.isnull().sum())
print("------------------------------------------")
print(drinks.dtypes)
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64
# ------------------------------------------
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# - 결측 데이터 채우기

# %%
drinks['continent'] = drinks['continent'].fillna('OT')
print(drinks.isnull().sum())
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %% [markdown]
# ## matplotlib.pyplot.pie
# - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html

# %%
labels = drinks['continent'].value_counts().index.tolist()
fracs1 = drinks['continent'].value_counts().values.tolist()
explode = (0.2,0,0,0,0,0)
plt.pie(fracs1,explode=explode, labels=labels, autopct='%.0f%%', shadow=True)
plt.title("NULL Data to 'OT''")
# Out:
# Text(0.5, 1.0, "NULL Data to 'OT''")

# %%
labels = drinks['continent'].value_counts().index.tolist()
labels # 값이 큰 순서대로
# Out:
# ['AF', 'EU', 'AS', 'OT', 'OC', 'SA']

# %%
fracs1 = drinks['continent'].value_counts().values.tolist()
fracs1
# Out:
# [53, 45, 44, 23, 16, 12]

# %%
plt.rcParams.update({'font.size':20}) # 폰트 크기
plt.figure(figsize=(10,10)) # 그림 크기
# plt.rc('font',size=20) # 폰트 크기
explode = (0,0.2,0,0,0,0)
plt.pie(fracs1,         # values 데이터값
    explode=explode,    # 파이에서 튀어나오는 위치
    labels=labels,      # labels
    colors=None,
    autopct='%.1f%%',
    pctdistance=0.6,
    shadow=True,
    labeldistance=1.1,
    startangle=230,    # 반시계방향으로 회전
    radius=None,
    counterclock=True, #시계방향으로 갈건지
    wedgeprops=None,
    textprops={'fontsize': 30}, # 폰트 크기 위에 2개의 폰트옵션은 파이 안에만 커짐
    center=(0, 0),
    frame=False,
    rotatelabels=False)
plt.show()
plt.rc('font',size=10) # 폰트크기를 원래대로 지정
plt.rcParams.update({'font.size':10})

# %%
result = drinks.groupby('continent').spirit_servings.\
                agg(['mean','min','max','sum','var','std']) # 역슬러쉬 쓰면 한줄 띄우고쓸수있음
result.head()
# Out:
#                  mean  min  max   sum          var        std
# continent
# AF          16.339623    0  152   866   789.767054  28.102794
# AS          60.840909    0  326  2677  7116.974101  84.362160
# EU         132.555556    0  373  5965  6020.070707  77.589115
# OC          58.437500    0  254   935  4970.929167  70.504817
# OT         165.739130   68  438  3812  9023.837945  94.993884

# %%
result = drinks.groupby('continent').beer_servings.\
                agg(['mean','min','max','sum','var','std']) # 역슬러쉬 쓰면 한줄 띄우고쓸수있음
result.head()
# Out:
#                  mean  min  max   sum          var        std
# continent
# AF          61.471698    0  376  3258  6489.561684  80.557816
# AS          37.045455    0  247  1630  2447.253700  49.469725
# EU         193.777778    0  361  8720  9926.449495  99.631569
# OC          89.687500    0  306  1435  9339.562500  96.641412
# OT         145.434783    1  285  3345  6339.529644  79.621163

# %%
result = drinks.groupby('continent').wine_servings.\
                agg(['mean','min','max','sum','var','std']) # 역슬러쉬 쓰면 한줄 띄우고쓸수있음
result.head()
# Out:
#                  mean  min  max   sum          var        std
# continent
# AF          16.264151    0  233   862  1509.044267  38.846419
# AS           9.068182    0  123   399   469.460359  21.667034
# EU         142.222222    0  370  6400  9490.994949  97.421738
# OC          35.625000    0  212   570  4167.450000  64.555790
# OT          24.521739    1  100   564   798.988142  28.266378

# %%
result = drinks.groupby('continent').total_litres_of_pure_alcohol.\
                agg(['mean','min','max','sum','var','std']) # 역슬러쉬 쓰면 한줄 띄우고쓸수있음
result.head()
# Out:
#                mean  min   max    sum        var       std
# continent
# AF         3.007547  0.0   9.1  159.4   7.009557  2.647557
# AS         2.170455  0.0  11.5   95.5   7.674223  2.770239
# EU         8.617778  0.0  14.4  387.8  11.279222  3.358455
# OC         3.381250  0.0  10.4   54.1  11.193625  3.345688
# OT         5.995652  2.2  11.9  137.9   5.804980  2.409353

# %% [markdown]
# - total_litres_of_pure_alcohol 의 평균

# %%
total_mean = drinks.total_litres_of_pure_alcohol.mean()
total_mean
# Out:
# 4.717098445595855

# %%
continent_mean = drinks.groupby('continent')\
                ['total_litres_of_pure_alcohol'].mean()
print(continent_mean)
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# OT    5.995652
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
continent_mean = drinks.groupby('continent')\
                .total_litres_of_pure_alcohol.mean()
print(continent_mean)
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# OT    5.995652
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
continent_over_mean = continent_mean[continent_mean >= total_mean]
print(continent_over_mean)
# Out:
# continent
# EU    8.617778
# OT    5.995652
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# - 평균 beer_servings 가 가장 높은 대륙
# - 평균 beer_servings 가 가장 낮은 대륙

# %%
beer_continent_mean = drinks.groupby('continent').beer_servings.mean()
beer_continent_mean
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# OT    145.434783
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
beer_continent_max = beer_continent_mean.max()
beer_continent_max
# Out:
# 193.77777777777777

# %%
beer_continent_min = beer_continent_mean.min()
beer_continent_min
# Out:
# 37.04545454545455

# %%
beer_continent_mean[beer_continent_mean==beer_continent_max]
# Out:
# continent
# EU    193.777778
# Name: beer_servings, dtype: float64

# %%
beer_continent_mean[beer_continent_mean==beer_continent_min]
# Out:
# continent
# AS    37.045455
# Name: beer_servings, dtype: float64

# %% [markdown]
# ## 시각화
# - 대륙별 spirit_serving의 평균, 최소, 최대, 합계를 시각화

# %%
result = drinks.groupby('continent').spirit_servings.agg(['mean','min','max','count'])
result.head()
# Out:
#                  mean  min  max  count
# continent
# AF          16.339623    0  152     53
# AS          60.840909    0  326     44
# EU         132.555556    0  373     45
# OC          58.437500    0  254     16
# OT         165.739130   68  438     23

# %%
num_groups = len(result.index)
num_groups
# Out:
# 6

# %%
means = result['mean'].tolist()
means
# Out:
# [16.339622641509433,
#  60.84090909090909,
#  132.55555555555554,
#  58.4375,
#  165.7391304347826,
#  114.75]

# %% [markdown]
# ## matplotlib.pyplot.bar
# - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.bar.html?highlight=bar#matplotlib.pyplot.bar

# %%
mins = result['min'].tolist()
maxs = result['max'].tolist()
counts = result['count'].tolist()
index = np.arange(num_groups)
plt.figure(figsize=(10,10))
bar_width = 0.2

rects_1 = plt.bar(index,means,bar_width, color='r', label='Mean')
rects_2 = plt.bar(index+bar_width,mins,bar_width, color='g', label='Min')
rects_3 = plt.bar(index+bar_width*2,maxs,bar_width, color='b', label='Max')
rects_4 = plt.bar(index+bar_width*3,counts,bar_width, color='y', label='Count')

plt.xticks(index, result.index.tolist())
plt.legend()
plt.show()

# %% [markdown]
# - 대륙별 total_litres_of_pure_alcohol 시각화

# %%
continent_mean = drinks.groupby('continent')\
                .total_litres_of_pure_alcohol.mean()
print(continent_mean)
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# OT    5.995652
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
continents = continent_mean.index.tolist()
continents
# Out:
# ['AF', 'AS', 'EU', 'OC', 'OT', 'SA']

# %%
continents.append('MEAN')
continents
# Out:
# ['AF', 'AS', 'EU', 'OC', 'OT', 'SA', 'MEAN']

# %%
x_pos = np.arange(len(continents))
x_pos
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
alcohol = continent_mean.tolist()
alcohol.append(total_mean)
alcohol
# Out:
# [3.00754716981132,
#  2.1704545454545454,
#  8.617777777777777,
#  3.3812500000000005,
#  5.995652173913044,
#  6.308333333333334,
#  4.717098445595855]

# %%
# plt.grid(b=True, which='both',axis=''both')      # 그리드 없을때
bar_list = plt.bar(x_pos, alcohol, align='center', alpha=0.9)
bar_list[len(continents) - 1].set_color('r')
plt.plot([0., 6], [total_mean, total_mean], "k--")
plt.xticks(x_pos, continents)

plt.ylabel('total_litres_of_pure_alcohol')
plt.title('total_litres_of_pure_alcohol by Continent')

plt.show()

# %%
# plt.grid(b=True, which='both',axis=''both')      # 그리드 없을때
bar_list = plt.bar(x_pos, alcohol, align='center', alpha=0.9)
bar_list[len(continents) - 1].set_color('g')
plt.plot([0., 6], [total_mean, total_mean], "k--")
plt.xticks(x_pos, continents)

plt.ylabel('total_litres_of_pure_alcohol')
plt.title('total_litres_of_pure_alcohol by Continent')

plt.show()

# %%
# plt.grid(b=True, which='both',axis=''both')      # 그리드 없을때
bar_list = plt.bar(x_pos, alcohol, align='center', alpha=0.9)
bar_list[len(continents) - 1].set_color('g')
plt.plot([3., 5], [continent_mean['SA'], continent_mean['SA']], "k--")
plt.xticks(x_pos, continents)

plt.ylabel('total_litres_of_pure_alcohol')
plt.title('total_litres_of_pure_alcohol by Continent')

plt.show()

# %%
africa = drinks.loc[drinks['continent']=='AF']
africa.head()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 2        Algeria             25                0             14
# 4         Angola            217               57             45
# 18         Benin             34                4             13
# 22      Botswana            173               35             35
# 26  Burkina Faso             25                7              7
#
#     total_litres_of_pure_alcohol continent
# 2                            0.7        AF
# 4                            5.9        AF
# 18                           1.1        AF
# 22                           5.4        AF
# 26                           4.3        AF

# %%
europe = drinks.loc[drinks['continent']=='EU']
europe.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 1      Albania             89              132             54
# 3      Andorra            245              138            312
# 7      Armenia             21              179             11
# 9      Austria            279               75            191
# 10  Azerbaijan             21               46              5
#
#     total_litres_of_pure_alcohol continent
# 1                            4.9        EU
# 3                           12.4        EU
# 7                            3.8        EU
# 9                            9.7        EU
# 10                           1.3        EU

# %%
drinks['total_servings'] =  drinks['beer_servings']+\
                            drinks['wine_servings']+\
                            drinks['spirit_servings']

# %%
drinks['alcohol_rate'] = drinks['total_litres_of_pure_alcohol']/drinks['total_servings']
drinks['alcohol_rate'] = drinks['alcohol_rate'].fillna(0)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_servings  alcohol_rate
# 0                           0.0        AS               0      0.000000
# 1                           4.9        EU             275      0.017818
# 2                           0.7        AF              39      0.017949
# 3                          12.4        EU             695      0.017842
# 4                           5.9        AF             319      0.018495

# %%
country_rank = drinks[['country','alcohol_rate']]
country_rank = country_rank.sort_values(by=['alcohol_rate'],ascending=0)
country_rank.head()
# Out:
#           country  alcohol_rate
# 63         Gambia      0.266667
# 153  Sierra Leone      0.223333
# 124       Nigeria      0.185714
# 179        Uganda      0.153704
# 142        Rwanda      0.151111

# %%
country_list = country_rank.country.tolist()
x_pos = np.arange(len(country_list))
rank = country_rank.alcohol_rate.tolist()
 
bar_list = plt.bar(x_pos, rank)
bar_list[country_list.index("South Korea")].set_color('r')
plt.ylabel('alcohol rate')
plt.title('liquor drink rank by contry')
plt.axis([0, 200, 0, 0.3])

korea_rank = country_list.index("South Korea")
korea_alc_rate = country_rank[country_rank['country'] == 'South Korea']['alcohol_rate'].values[0]
plt.annotate('South Korea : ' + str(korea_rank + 1), 
             xy=(korea_rank, korea_alc_rate), 
             xytext=(korea_rank + 10, korea_alc_rate + 0.05),
             arrowprops=dict(facecolor='red', shrink=0.05))

plt.show()

# %% [markdown]
# - total_litres_of_pure_alcohol 평균을 구하기
# - 이 평균값보다 적은 알코올을 섭취하는 대륙중에서 spirit을 가장 많이 마시는 국가를 구해보자

# %%
drinks['total_litres_of_pure_alcohol'].mean()
# Out:
# 4.717098445595855

# %%
drinks2=drinks.copy()
con_m=drinks2.groupby('continent').total_litres_of_pure_alcohol.mean()
con_m
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# OT    5.995652
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
con_m2=con_m[con_m < drinks['total_litres_of_pure_alcohol'].mean()]
con_m2
# Out:
# continent
# AF    3.007547
# AS    2.170455
# OC    3.381250
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
con=con_m2.index.tolist()
con
# Out:
# ['AF', 'AS', 'OC']

# %%
drinks2['con']=drinks2['continent'].isin(con)
drinks2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 0                             0.0        AS               0      0.000000
# ...

# %%
drinks2[drinks2['con']==True]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 2        Algeria             25                0             14
# 4         Angola            217               57             45
# 8      Australia            261               72            212
# 12       Bahrain             42               63              7
# ..           ...            ...              ...            ...
# 187      Vanuatu             21               18             11
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 0                             0.0        AS               0      0.000000
# ...

# %%
drmax=drinks2['spirit_servings'][drinks2['con']==True].max()
drmax
# Out:
# 326

# %%
drinks2['country'][(drinks2['spirit_servings'] == drmax) & (drinks2['con']==True)]
# Out:
# 141    Russian Federation
# Name: country, dtype: object

# %%
drinks2['con_spi']=(drinks2['spirit_servings'] == drmax) & (drinks2['con']==True)
drinks2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 0                             0.0        AS               0      0.000000
# ...

# %%
drinks2[drinks2['con_spi']==True]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 141  Russian Federation            247              326             73
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 141                          11.5        AS             646      0.017802
#
#       con  con_spi
# 141  True     True

# %% [markdown]
# ## 밑에는 뻘짓... 대륙기준 아니고 국가별 total_litres_of_pure_alcohol 평균보다 낮은기준

# %%
drinks2['als']=drinks['total_litres_of_pure_alcohol']<drinks['total_litres_of_pure_alcohol'].mean()
drinks2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 0                             0.0        AS               0      0.000000
# ...

# %%
drinks2=drinks2[drinks2['als']==True]
drinks2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 2        Algeria             25                0             14
# 7        Armenia             21              179             11
# 10    Azerbaijan             21               46              5
# 12       Bahrain             42               63              7
# ..           ...            ...              ...            ...
# 187      Vanuatu             21               18             11
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 0                             0.0        AS               0      0.000000
# ...

# %%
drinks2['spirit_servings'].max()
# Out:
# 186

# %%
drinks2['als2']=drinks2['spirit_servings']==drinks2['spirit_servings'].max()
drinks2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 2        Algeria             25                0             14
# 7        Armenia             21              179             11
# 10    Azerbaijan             21               46              5
# 12       Bahrain             42               63              7
# ..           ...            ...              ...            ...
# 187      Vanuatu             21               18             11
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 0                             0.0        AS               0      0.000000
# ...

# %%
drinks2[drinks2['als2']==True]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 134  Philippines             71              186              1
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate  \
# 134                           4.6        AS             258      0.017829
#
#       con  con_spi   als  als2
# 134  True    False  True  True
